# %% [markdown]
# # Add new column

# %%
import pandas as pd
nba=pd.read_csv("nba.csv")

# %% [raw]
# We know that when we access a column which is not available in dataframe, we will get a error

# %%
#For example
nba["sport"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sport'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-553560595856> in <module>
# ----> 1 nba["sport"]
#
# ...

# %%
#nba["Sport"]="Basket ball " willc create a new column and gives the value for all the rows
#Remember it permanently modifies the dataframe
#On the right side you can assign a pandas series as well
nba["Sport"]="Basket ball"
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary        Sport
# 0              Texas  7730337.0  Basket ball
# 1          Marquette  6796117.0  Basket ball
# 2  Boston University        NaN  Basket ball
# 3      Georgia State  1148640.0  Basket ball
# 4                NaN  5000000.0  Basket ball

# %%
#Method 2 using insert method
nba.insert(2,"League","National Basketball Assocition")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-d42ff7950829> in <module>
#       1 #Method 2 using insert method
# ----> 2 nba.insert(2,"League","National Basketball Assocition")
#       3 nba.head(5)
#       4 nba.columns
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3471         value = self._sanitize_column(column, value, broadcast=False)
#    3472         self._data.insert(loc, column, value,
# -> 3473                           allow_duplicates=allow_duplicates)
#    3474
#    3475     def assign(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1147         if not allow_duplicates and item in self.items:
#    1148             # Should this be a different kind of error??
# ...

# %%
nba.head(5)
# Out:
#             Name            Team                         Leaguee  \
# 0  Avery Bradley  Boston Celtics  National Basketball Assocition
# 1    Jae Crowder  Boston Celtics  National Basketball Assocition
# 2   John Holland  Boston Celtics  National Basketball Assocition
# 3    R.J. Hunter  Boston Celtics  National Basketball Assocition
# 4  Jonas Jerebko  Boston Celtics  National Basketball Assocition
#
#                            League  Number Position   Age Height  Weight  \
# 0  National Basketball Assocition     0.0       PG  25.0    6-2   180.0
# 1  National Basketball Assocition    99.0       SF  25.0    6-6   235.0
# 2  National Basketball Assocition    30.0       SG  27.0    6-5   205.0
# 3  National Basketball Assocition    28.0       SG  22.0    6-5   185.0
# 4  National Basketball Assocition     8.0       PF  29.0   6-10   231.0
#
#              College     Salary        Sport
# 0              Texas  7730337.0  Basket ball
# 1          Marquette  6796117.0  Basket ball
# ...
